# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/filtered-ava/filtered_val_data.csv
# /kaggle/input/filtered-ava/filtered_train_data.csv

# %%
# !pip install pytube moviepy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 9.1 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 62.9 MB/s eta 0:00:00:00:0100:01
# ...
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110721 sha256=5d08b8996fa9f1f685e6fc5bdea783aa20ea4d7e8cb9cfa5d4653bd6fb8d203d
#   Stored in directory: /root/.cache/pip/wheels/96/32/2d/e10123bd88fbfc02fed53cc18c80a171d3c87479ed845fa7c1
# Successfully built moviepy
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# ...

# %%
# !pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 4.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 52.3 MB/s eta 0:00:00:00:01
# ...

# %%
import os
import pandas as pd
from yt_dlp import YoutubeDL
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip

# Paths
BASE_PATH = '/kaggle/input/filtered-ava'  # Base path for the dataset
CLIP_SAVE_PATH = '/kaggle/working/clips/'  # Path to save video clips

# Ensure the save path exists
os.makedirs(CLIP_SAVE_PATH, exist_ok=True)

# Load the filtered data
data_path = os.path.join(BASE_PATH, 'filtered_train_data.csv')
data = pd.read_csv(filtered_data_path)

def download_youtube_segment(video_id, start_time, end_time, save_path):
    """Download a YouTube video and save only the required segment."""
    try:
        # Construct URL
        url = f'https://www.youtube.com/watch?v={video_id}'
        
        # Define output path for the complete video
        video_filename = os.path.join(save_path, f"{video_id}.mp4")
        
        # Set up yt-dlp options
        ydl_opts = {
            'format': 'bestvideo+bestaudio/best',  # Get the best quality
            'outtmpl': video_filename,              # Save path for full video
            'quiet': True,                          # Minimize output
        }
        
        # Download video
        with YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
        
        # Define output path for the segment
        segment_filename = os.path.join(save_path, f"{video_id}_segment_{start_time}_{end_time}.mp4")
        
        # Extract the required clip using ffmpeg
        ffmpeg_extract_subclip(video_filename, start_time, end_time, targetname=segment_filename)
        
        # Optionally, remove the full downloaded video to save space
        os.remove(video_filename)
        
        return segment_filename
    except Exception as e:
        print(f"Failed to download or extract segment for video {video_id} at {start_time}-{end_time}: {e}")
        return None

# %%
save_path = '/kaggle/working/clips/'
clip_duration = 2
video_id = '-5KQ66BBWC4'

timestamp = 922
start_time = max(0, timestamp - clip_duration // 2)  # Ensure non-negative start time
end_time = start_time + clip_duration
segment_path = download_youtube_segment(video_id, start_time, end_time, save_path)
if segment_path:
    print(f"Downloaded segment: {segment_path}")
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Downloaded segment: /kaggle/working/clips/-5KQ66BBWC4_segment_921_923.mp4

# %%
# Download and extract each segment
for idx, row in data.iterrows():
    video_id = row['video_id']
    timestamp = row['middle_frame_timestamp']
    start_time = max(0, timestamp - clip_duration // 2)  # Ensure non-negative start time
    end_time = start_time + clip_duration
    
    segment_path = download_youtube_segment(video_id, start_time, end_time, save_path)
    if segment_path:
        print(f"Downloaded segment: {segment_path}")
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Downloaded segment: /kaggle/working/clips/-5KQ66BBWC4_segment_921_923.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Downloaded segment: /kaggle/working/clips/-5KQ66BBWC4_segment_922_924.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Downloaded segment: /kaggle/working/clips/-5KQ66BBWC4_segment_924_926.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Downloaded segment: /kaggle/working/clips/-5KQ66BBWC4_segment_924_926.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Downloaded segment: /kaggle/working/clips/-5KQ66BBWC4_segment_925_927.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Downloaded segment: /kaggle/working/clips/-5KQ66BBWC4_segment_931_933.mp4
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ...

# %%
from IPython.display import Video
Video('/kaggle/working/clips/-5KQ66BBWC4_segment_933_935.mp4', embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
